# %% [markdown]
# <a href="https://colab.research.google.com/github/artiboi2002/dp-poisoning-attacks/blob/main/Experiment_2_0_Poisoned_Label_Flipping_Model_With_No_DP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

def apply_label_flipping(dataset, flip_rate=0.1, seed=42):
    torch.manual_seed(seed)
    n_samples = len(dataset)
    n_flip = int(n_samples * flip_rate)
    flip_indices = torch.randperm(n_samples)[:n_flip]

    for idx in flip_indices:
        original = dataset.targets[idx].item()
        new_label = torch.randint(0, 10, (1,)).item()
        while new_label == original:
            new_label = torch.randint(0, 10, (1,)).item()
        dataset.targets[idx] = new_label

    return dataset

transform = transforms.ToTensor()

#Train Data
trainData = datasets.MNIST(root='./cnn_data', train=True, download=True, transform=transform)
trainData = apply_label_flipping(trainData, flip_rate=0.1) #In the training data we include label flipping attack

#Test Data
testData = datasets.MNIST(root='./cnn_data', train=False, download=True, transform=transform)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.7MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 511kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.93MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.96MB/s]

# %%
class ConvolutionalNeuralNetwork(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Conv2d(1, 6, 3, 1)
    self.conv2 = nn.Conv2d(6, 16, 3,1)
    # Fully connected layer
    self.fc1 = nn.Linear(5*5*16, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = F.max_pool2d(x, 2,2) #2x2 kernal and a stride of 2
    x = F.relu(self.conv2(x)) #1 image, 6 output, 3 kernal, 1 stride
    x = F.max_pool2d(x, 2, 2)

    #Review to flatten in out
    x = x.view(-1, 16*5*5)

    #Fully connected layers
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)

    return F.log_softmax(x, dim = 1)

# %%
def trainingFunction(model, train_loader,test_loader, epochs, criterion, optimizer):
  train_loss = []
  test_loss = []
  train_correct =[]
  test_correct = []

 #For loop of Epochs
  for i in range(epochs):
    train_corr = 0
    test_corr = 0
    total_samples = 0
    test_total_samples = 0


  #Train
    for b,(X_train, Y_train) in enumerate(train_loader):
      b += 1 #start our batches at 1
      y_pred = model(X_train) #get the predicted values from the training set. Not flaattedned 2D
      loss = criterion(y_pred, Y_train) #How off are we? Compare the prediction to the correct answers in Y_train
      predicted = torch.max(y_pred.data, 1)[1] #we want to add up the correct number of prediciton. Indexed of the first point
      batch_corr = (predicted == Y_train).sum() #we want to know how many we got correct.
      train_corr += batch_corr #keep track as we go aloing in training
      total_samples += Y_train.size(0)

    #Update the parameters
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      if b % 600 == 0:
        print(f'Epoch: {i+1}, Batch {b}, Loss {loss.item(): .4f}')

  #append train loss and train correct into the list
    train_loss.append(loss.item())
    train_correct.append(train_corr.item())

  #Test
    with torch.no_grad():
      for b,(X_test, Y_test) in enumerate(test_loader):
        y_value = model(X_test)
        loss = criterion(y_value, Y_test)
        predicted = torch.max(y_value.data, 1)[1]
        test_corr += (predicted == Y_test).sum()
        test_total_samples += Y_test.size(0)

 #append test loss and train correct into the list
    test_loss.append(loss.item())
    test_correct.append(test_corr.item())
    train_accuracy = 100 * train_corr.item() / total_samples
    test_accuracy = 100 * test_corr.item() / test_total_samples
    print(f"Epoch {i + 1} — Train Accuracy: {train_accuracy:.2f}%")
    print(f"Epoch {i + 1} — Test Accuracy: {test_accuracy:.2f}%")


  return train_loss, test_loss, train_correct, test_correct

# %%
torch.manual_seed(41)
model = ConvolutionalNeuralNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001) #Smaller the learning rate the longer is gonna take to train
trainLoader = DataLoader(trainData, batch_size=10, shuffle = True)
testLoader = DataLoader(testData, batch_size=10, shuffle = False)
epochs = 15

train_loss, test_loss, train_correct, test_correct = trainingFunction(
    model, trainLoader, testLoader, epochs, criterion, optimizer
)
# Out:
# Epoch: 1, Batch 600, Loss  2.2999
# Epoch: 1, Batch 1200, Loss  2.2822
# Epoch: 1, Batch 1800, Loss  2.2861
# Epoch: 1, Batch 2400, Loss  2.2984
# Epoch: 1, Batch 3000, Loss  2.2872
# Epoch: 1, Batch 3600, Loss  2.2984
# Epoch: 1, Batch 4200, Loss  2.2995
# Epoch: 1, Batch 4800, Loss  2.2980
# Epoch: 1, Batch 5400, Loss  2.2825
# Epoch: 1, Batch 6000, Loss  2.2884
# Epoch 1 — Train Accuracy: 16.46%
# Epoch 1 — Test Accuracy: 29.16%
# Epoch: 2, Batch 600, Loss  2.2532
# Epoch: 2, Batch 1200, Loss  2.2683
# Epoch: 2, Batch 1800, Loss  2.2607
# Epoch: 2, Batch 2400, Loss  2.2675
# Epoch: 2, Batch 3000, Loss  2.2079
# Epoch: 2, Batch 3600, Loss  2.1392
# Epoch: 2, Batch 4200, Loss  1.9422
# Epoch: 2, Batch 4800, Loss  1.7099
# Epoch: 2, Batch 5400, Loss  1.3973
# Epoch: 2, Batch 6000, Loss  1.6475
# Epoch 2 — Train Accuracy: 42.14%
# Epoch 2 — Test Accuracy: 65.58%
# Epoch: 3, Batch 600, Loss  1.0721
# Epoch: 3, Batch 1200, Loss  1.0057
# Epoch: 3, Batch 1800, Loss  0.7222
# Epoch: 3, Batch 2400, Loss  0.7973
# Epoch: 3, Batch 3000, Loss  1.4067
# Epoch: 3, Batch 3600, Loss  1.6391
# Epoch: 3, Batch 4200, Loss  0.8193
# Epoch: 3, Batch 4800, Loss  1.4006
# Epoch: 3, Batch 5400, Loss  2.1530
# Epoch: 3, Batch 6000, Loss  0.7289
# Epoch 3 — Train Accuracy: 72.65%
# Epoch 3 — Test Accuracy: 87.48%
# Epoch: 4, Batch 600, Loss  0.4147
# Epoch: 4, Batch 1200, Loss  0.6834
# Epoch: 4, Batch 1800, Loss  0.2131
# Epoch: 4, Batch 2400, Loss  0.6832
# Epoch: 4, Batch 3000, Loss  0.6867
# Epoch: 4, Batch 3600, Loss  0.9198
# Epoch: 4, Batch 4200, Loss  0.9543
# Epoch: 4, Batch 4800, Loss  0.7464
# Epoch: 4, Batch 5400, Loss  0.9735
# Epoch: 4, Batch 6000, Loss  1.7891
# Epoch 4 — Train Accuracy: 79.27%
# Epoch 4 — Test Accuracy: 88.76%
# Epoch: 5, Batch 600, Loss  1.1944
# Epoch: 5, Batch 1200, Loss  0.6114
# Epoch: 5, Batch 1800, Loss  1.7757
# Epoch: 5, Batch 2400, Loss  1.1289
# Epoch: 5, Batch 3000, Loss  0.8738
# Epoch: 5, Batch 3600, Loss  0.4755
# Epoch: 5, Batch 4200, Loss  0.3611
# Epoch: 5, Batch 4800, Loss  0.2866
# Epoch: 5, Batch 5400, Loss  1.0852
# Epoch: 5, Batch 6000, Loss  0.4155
# Epoch 5 — Train Accuracy: 81.41%
# Epoch 5 — Test Accuracy: 91.88%
# Epoch: 6, Batch 600, Loss  0.6495
# Epoch: 6, Batch 1200, Loss  0.6741
# Epoch: 6, Batch 1800, Loss  0.4982
# Epoch: 6, Batch 2400, Loss  1.2287
# Epoch: 6, Batch 3000, Loss  0.1926
# Epoch: 6, Batch 3600, Loss  0.4311
# Epoch: 6, Batch 4200, Loss  0.3409
# Epoch: 6, Batch 4800, Loss  0.3024
# Epoch: 6, Batch 5400, Loss  1.1706
# Epoch: 6, Batch 6000, Loss  0.2514
# Epoch 6 — Train Accuracy: 83.14%
# Epoch 6 — Test Accuracy: 93.87%
# Epoch: 7, Batch 600, Loss  0.5614
# Epoch: 7, Batch 1200, Loss  0.5795
# Epoch: 7, Batch 1800, Loss  0.6608
# Epoch: 7, Batch 2400, Loss  0.1972
# Epoch: 7, Batch 3000, Loss  0.4480
# Epoch: 7, Batch 3600, Loss  0.8990
# Epoch: 7, Batch 4200, Loss  1.0311
# Epoch: 7, Batch 4800, Loss  0.6161
# Epoch: 7, Batch 5400, Loss  0.4613
# Epoch: 7, Batch 6000, Loss  0.2405
# Epoch 7 — Train Accuracy: 84.30%
# Epoch 7 — Test Accuracy: 94.65%
# Epoch: 8, Batch 600, Loss  0.7408
# Epoch: 8, Batch 1200, Loss  0.7228
# Epoch: 8, Batch 1800, Loss  1.2720
# Epoch: 8, Batch 2400, Loss  0.3899
# Epoch: 8, Batch 3000, Loss  0.7839
# Epoch: 8, Batch 3600, Loss  0.6090
# Epoch: 8, Batch 4200, Loss  1.3115
# Epoch: 8, Batch 4800, Loss  0.8590
# Epoch: 8, Batch 5400, Loss  1.0398
# Epoch: 8, Batch 6000, Loss  0.4203
# Epoch 8 — Train Accuracy: 85.14%
# Epoch 8 — Test Accuracy: 94.90%
# Epoch: 9, Batch 600, Loss  0.7023
# Epoch: 9, Batch 1200, Loss  0.6130
# Epoch: 9, Batch 1800, Loss  0.8185
# Epoch: 9, Batch 2400, Loss  0.3184
# Epoch: 9, Batch 3000, Loss  0.3812
# Epoch: 9, Batch 3600, Loss  0.4753
# Epoch: 9, Batch 4200, Loss  0.1373
# Epoch: 9, Batch 4800, Loss  0.1663
# Epoch: 9, Batch 5400, Loss  0.9050
# Epoch: 9, Batch 6000, Loss  1.1777
# Epoch 9 — Train Accuracy: 85.75%
# Epoch 9 — Test Accuracy: 95.82%
# Epoch: 10, Batch 600, Loss  0.7709
# Epoch: 10, Batch 1200, Loss  0.5145
# Epoch: 10, Batch 1800, Loss  0.2108
# Epoch: 10, Batch 2400, Loss  0.2290
# Epoch: 10, Batch 3000, Loss  0.7113
# Epoch: 10, Batch 3600, Loss  1.6000
# Epoch: 10, Batch 4200, Loss  0.1585
# Epoch: 10, Batch 4800, Loss  0.5029
# Epoch: 10, Batch 5400, Loss  0.2774
# Epoch: 10, Batch 6000, Loss  0.3427
# Epoch 10 — Train Accuracy: 86.16%
# Epoch 10 — Test Accuracy: 95.98%
# Epoch: 11, Batch 600, Loss  0.3969
# Epoch: 11, Batch 1200, Loss  0.2622
# Epoch: 11, Batch 1800, Loss  0.1786
# Epoch: 11, Batch 2400, Loss  0.1316
# Epoch: 11, Batch 3000, Loss  0.3402
# Epoch: 11, Batch 3600, Loss  0.2372
# Epoch: 11, Batch 4200, Loss  1.4303
# Epoch: 11, Batch 4800, Loss  0.4923
# Epoch: 11, Batch 5400, Loss  0.8291
# Epoch: 11, Batch 6000, Loss  0.1795
# Epoch 11 — Train Accuracy: 86.41%
# Epoch 11 — Test Accuracy: 96.53%
# Epoch: 12, Batch 600, Loss  1.4197
# Epoch: 12, Batch 1200, Loss  0.7169
# Epoch: 12, Batch 1800, Loss  1.2159
# Epoch: 12, Batch 2400, Loss  0.7370
# Epoch: 12, Batch 3000, Loss  1.2397
# Epoch: 12, Batch 3600, Loss  0.2474
# Epoch: 12, Batch 4200, Loss  0.6007
# Epoch: 12, Batch 4800, Loss  0.1233
# Epoch: 12, Batch 5400, Loss  0.4927
# Epoch: 12, Batch 6000, Loss  0.1279
# Epoch 12 — Train Accuracy: 86.64%
# Epoch 12 — Test Accuracy: 96.92%
# Epoch: 13, Batch 600, Loss  0.2862
# Epoch: 13, Batch 1200, Loss  0.6948
# Epoch: 13, Batch 1800, Loss  0.9712
# Epoch: 13, Batch 2400, Loss  1.0835
# Epoch: 13, Batch 3000, Loss  1.1703
# Epoch: 13, Batch 3600, Loss  1.3206
# Epoch: 13, Batch 4200, Loss  0.2407
# Epoch: 13, Batch 4800, Loss  1.1629
# Epoch: 13, Batch 5400, Loss  1.7376
# Epoch: 13, Batch 6000, Loss  1.1076
# Epoch 13 — Train Accuracy: 86.92%
# Epoch 13 — Test Accuracy: 97.01%
# Epoch: 14, Batch 600, Loss  0.1366
# Epoch: 14, Batch 1200, Loss  0.6838
# Epoch: 14, Batch 1800, Loss  0.6045
# Epoch: 14, Batch 2400, Loss  0.1292
# Epoch: 14, Batch 3000, Loss  1.0622
# Epoch: 14, Batch 3600, Loss  0.3863
# Epoch: 14, Batch 4200, Loss  0.3252
# Epoch: 14, Batch 4800, Loss  1.1540
# Epoch: 14, Batch 5400, Loss  0.2463
# Epoch: 14, Batch 6000, Loss  0.2036
# Epoch 14 — Train Accuracy: 87.12%
# Epoch 14 — Test Accuracy: 97.25%
# Epoch: 15, Batch 600, Loss  1.3932
# Epoch: 15, Batch 1200, Loss  0.1144
# Epoch: 15, Batch 1800, Loss  0.4739
# Epoch: 15, Batch 2400, Loss  0.2354
# Epoch: 15, Batch 3000, Loss  1.0555
# Epoch: 15, Batch 3600, Loss  0.2088
# Epoch: 15, Batch 4200, Loss  1.8812
# Epoch: 15, Batch 4800, Loss  1.3675
# Epoch: 15, Batch 5400, Loss  1.3536
# Epoch: 15, Batch 6000, Loss  0.3371
# Epoch 15 — Train Accuracy: 87.28%
# Epoch 15 — Test Accuracy: 97.43%

# %%
def compute_accuracy(correct_list, total_samples):
    return [100 * (x / total_samples) for x in correct_list]

train_acc = compute_accuracy(train_correct, len(trainLoader.dataset))
test_acc = compute_accuracy(test_correct, len(testLoader.dataset))

plt.figure(figsize=(12, 5))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(test_loss, label='Test Loss')
plt.title('Loss per Epoch (Poisoned Label Flipping Attack CNN)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Accuracy')
plt.plot(test_acc, label='Test Accuracy')
plt.title('Accuracy per Epoch (Poisoned Label Flipping Attack CNN)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()
