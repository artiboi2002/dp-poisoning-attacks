# %% [markdown]
# <a href="https://colab.research.google.com/github/artiboi2002/dp-poisoning-attacks/blob/main/Experiment_2_Posioned_Model_With_No_DP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
from opacus import PrivacyEngine
import time

def apply_label_flipping(dataset, flip_rate=0.1, seed=42):
    torch.manual_seed(seed)
    n_samples = len(dataset)
    n_flip = int(n_samples * flip_rate)
    flip_indices = torch.randperm(n_samples)[:n_flip]

    for idx in flip_indices:
        original = dataset.targets[idx].item()
        new_label = torch.randint(0, 10, (1,)).item()
        while new_label == original:
            new_label = torch.randint(0, 10, (1,)).item()
        dataset.targets[idx] = new_label

    return dataset


def apply_backdoor_attack(dataset, trigger_label=0, poison_fraction=0.01, patch_size=3):
    num_poison = int(len(dataset) * poison_fraction)
    indices = torch.randperm(len(dataset))[:num_poison]

    for idx in indices:
        image, _ = dataset[idx]
        image[0, 0:patch_size, 0:patch_size] = 1.0  # white square patch (top-left)
        dataset.data[idx] = (image * 255).byte()
        dataset.targets[idx] = trigger_label  # all patched images labeled as `trigger_label`

    return dataset

transform = transforms.ToTensor()

#Train Data
trainData = datasets.MNIST(root='./cnn_data', train=True, download=True, transform=transform)

trainData = apply_label_flipping(trainData, flip_rate=0.1) #In the training data we include label flipping attack
trainData = apply_backdoor_attack(trainData, trigger_label=0, poison_fraction=0.01) #in the training data we apply backdoor attack.

#Test Data
testData = datasets.MNIST(root='./cnn_data', train=False, download=True, transform=transform)
# Out:
# 🔁 Flipped 6000 labels (randomly)
# 🎯 Backdoored 600 images with label 0

# %%
class ConvolutionalNeuralNetwork(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Conv2d(1, 6, 3, 1)
    self.conv2 = nn.Conv2d(6, 16, 3,1)
    # Fully connected layer
    self.fc1 = nn.Linear(5*5*16, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = F.max_pool2d(x, 2,2) #2x2 kernal and a stride of 2
    x = F.relu(self.conv2(x)) #1 image, 6 output, 3 kernal, 1 stride
    x = F.max_pool2d(x, 2, 2)

    #Review to flatten in out
    x = x.view(-1, 16*5*5)

    #Fully connected layers
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)

    return F.log_softmax(x, dim = 1)

# %%
def trainingFunction(model, train_loader,test_loader, epochs, criterion, optimizer):
  train_loss = []
  test_loss = []
  train_correct =[]
  test_correct = []

 #For loop of Epochs
  for i in range(epochs):
    train_corr = 0
    test_corr = 0
    total_samples = 0
    test_total_samples = 0


  #Train
    for b,(X_train, Y_train) in enumerate(train_loader):
      b += 1 #start our batches at 1
      y_pred = model(X_train) #get the predicted values from the training set. Not flaattedned 2D
      loss = criterion(y_pred, Y_train) #How off are we? Compare the prediction to the correct answers in Y_train
      predicted = torch.max(y_pred.data, 1)[1] #we want to add up the correct number of prediciton. Indexed of the first point
      batch_corr = (predicted == Y_train).sum() #we want to know how many we got correct.
      train_corr += batch_corr #keep track as we go aloing in training
      total_samples += Y_train.size(0)

    #Update the parameters
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      if b % 600 == 0:
        print(f'Epoch: {i+1}, Batch {b}, Loss {loss.item(): .4f}')

  #append train loss and train correct into the list
    train_loss.append(loss.item())
    train_correct.append(train_corr.item())

  #Test
    with torch.no_grad():
      for b,(X_test, Y_test) in enumerate(test_loader):
        y_value = model(X_test)
        loss = criterion(y_value, Y_test)
        predicted = torch.max(y_value.data, 1)[1]
        test_corr += (predicted == Y_test).sum()
        test_total_samples += Y_test.size(0)

 #append test loss and train correct into the list
    test_loss.append(loss.item())
    test_correct.append(test_corr.item())
    train_accuracy = 100 * train_corr.item() / total_samples
    test_accuracy = 100 * test_corr.item() / test_total_samples
    print(f"Epoch {i + 1} — Train Accuracy: {train_accuracy:.2f}%")
    print(f"Epoch {i + 1} — Test Accuracy: {test_accuracy:.2f}%")


  return train_loss, test_loss, train_correct, test_correct

# %%
torch.manual_seed(41)
model = ConvolutionalNeuralNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001) #Smaller the learning rate the longer is gonna take to train
trainLoader = DataLoader(trainData, batch_size=10, shuffle = True)
testLoader = DataLoader(testData, batch_size=10, shuffle = False)
epochs = 15

train_loss, test_loss, train_correct, test_correct = trainingFunction(
    model, trainLoader, testLoader, epochs, criterion, optimizer
)
# Out:
# Epoch: 1, Batch 600, Loss  2.2998
# Epoch: 1, Batch 1200, Loss  2.2816
# Epoch: 1, Batch 1800, Loss  2.2981
# Epoch: 1, Batch 2400, Loss  2.3010
# Epoch: 1, Batch 3000, Loss  2.2873
# Epoch: 1, Batch 3600, Loss  2.3051
# Epoch: 1, Batch 4200, Loss  2.3001
# Epoch: 1, Batch 4800, Loss  2.2985
# Epoch: 1, Batch 5400, Loss  2.2887
# Epoch: 1, Batch 6000, Loss  2.2835
# Epoch 1 — Train Accuracy: 18.29%
# Epoch 1 — Test Accuracy: 31.94%
# Epoch: 2, Batch 600, Loss  2.2541
# Epoch: 2, Batch 1200, Loss  2.2770
# Epoch: 2, Batch 1800, Loss  2.2706
# Epoch: 2, Batch 2400, Loss  2.2607
# Epoch: 2, Batch 3000, Loss  2.2062
# Epoch: 2, Batch 3600, Loss  2.1120
# Epoch: 2, Batch 4200, Loss  1.9614
# Epoch: 2, Batch 4800, Loss  1.7727
# Epoch: 2, Batch 5400, Loss  1.4973
# Epoch: 2, Batch 6000, Loss  1.6820
# Epoch 2 — Train Accuracy: 36.10%
# Epoch 2 — Test Accuracy: 63.76%
# Epoch: 3, Batch 600, Loss  1.1361
# Epoch: 3, Batch 1200, Loss  1.0112
# Epoch: 3, Batch 1800, Loss  1.3125
# Epoch: 3, Batch 2400, Loss  0.8059
# Epoch: 3, Batch 3000, Loss  1.4320
# Epoch: 3, Batch 3600, Loss  1.6156
# Epoch: 3, Batch 4200, Loss  0.8359
# Epoch: 3, Batch 4800, Loss  1.4095
# Epoch: 3, Batch 5400, Loss  2.4750
# Epoch: 3, Batch 6000, Loss  0.7501
# Epoch 3 — Train Accuracy: 71.44%
# Epoch 3 — Test Accuracy: 87.29%
# Epoch: 4, Batch 600, Loss  0.4270
# Epoch: 4, Batch 1200, Loss  1.2313
# Epoch: 4, Batch 1800, Loss  0.2412
# Epoch: 4, Batch 2400, Loss  0.7021
# Epoch: 4, Batch 3000, Loss  0.7099
# Epoch: 4, Batch 3600, Loss  0.9212
# Epoch: 4, Batch 4200, Loss  0.9838
# Epoch: 4, Batch 4800, Loss  1.0929
# Epoch: 4, Batch 5400, Loss  0.8697
# Epoch: 4, Batch 6000, Loss  1.7822
# Epoch 4 — Train Accuracy: 78.36%
# Epoch 4 — Test Accuracy: 88.68%
# Epoch: 5, Batch 600, Loss  1.2122
# Epoch: 5, Batch 1200, Loss  0.6406
# Epoch: 5, Batch 1800, Loss  1.7890
# Epoch: 5, Batch 2400, Loss  1.1370
# Epoch: 5, Batch 3000, Loss  0.8542
# Epoch: 5, Batch 3600, Loss  0.4926
# Epoch: 5, Batch 4200, Loss  0.3764
# Epoch: 5, Batch 4800, Loss  0.2922
# Epoch: 5, Batch 5400, Loss  1.0622
# Epoch: 5, Batch 6000, Loss  0.4285
# Epoch 5 — Train Accuracy: 80.57%
# Epoch 5 — Test Accuracy: 91.65%
# Epoch: 6, Batch 600, Loss  0.6513
# Epoch: 6, Batch 1200, Loss  0.7040
# Epoch: 6, Batch 1800, Loss  0.5169
# Epoch: 6, Batch 2400, Loss  1.2419
# Epoch: 6, Batch 3000, Loss  0.4228
# Epoch: 6, Batch 3600, Loss  0.4475
# Epoch: 6, Batch 4200, Loss  0.3488
# Epoch: 6, Batch 4800, Loss  0.3031
# Epoch: 6, Batch 5400, Loss  1.1692
# Epoch: 6, Batch 6000, Loss  0.2552
# Epoch 6 — Train Accuracy: 82.24%
# Epoch 6 — Test Accuracy: 93.70%
# Epoch: 7, Batch 600, Loss  0.5787
# Epoch: 7, Batch 1200, Loss  0.6638
# Epoch: 7, Batch 1800, Loss  0.6635
# Epoch: 7, Batch 2400, Loss  0.1999
# Epoch: 7, Batch 3000, Loss  0.4552
# Epoch: 7, Batch 3600, Loss  0.8920
# Epoch: 7, Batch 4200, Loss  0.9978
# Epoch: 7, Batch 4800, Loss  0.6212
# Epoch: 7, Batch 5400, Loss  0.4845
# Epoch: 7, Batch 6000, Loss  0.4704
# Epoch 7 — Train Accuracy: 83.52%
# Epoch 7 — Test Accuracy: 94.78%
# Epoch: 8, Batch 600, Loss  0.6691
# Epoch: 8, Batch 1200, Loss  0.7439
# Epoch: 8, Batch 1800, Loss  1.2980
# Epoch: 8, Batch 2400, Loss  0.5538
# Epoch: 8, Batch 3000, Loss  0.7658
# Epoch: 8, Batch 3600, Loss  0.5839
# Epoch: 8, Batch 4200, Loss  1.3613
# Epoch: 8, Batch 4800, Loss  0.8437
# Epoch: 8, Batch 5400, Loss  1.1264
# Epoch: 8, Batch 6000, Loss  0.4343
# Epoch 8 — Train Accuracy: 84.32%
# Epoch 8 — Test Accuracy: 94.69%
# Epoch: 9, Batch 600, Loss  0.8220
# Epoch: 9, Batch 1200, Loss  0.6382
# Epoch: 9, Batch 1800, Loss  0.7794
# Epoch: 9, Batch 2400, Loss  0.3429
# Epoch: 9, Batch 3000, Loss  0.3736
# Epoch: 9, Batch 3600, Loss  0.4793
# Epoch: 9, Batch 4200, Loss  0.1441
# Epoch: 9, Batch 4800, Loss  0.1697
# Epoch: 9, Batch 5400, Loss  0.9332
# Epoch: 9, Batch 6000, Loss  1.1074
# Epoch 9 — Train Accuracy: 84.99%
# Epoch 9 — Test Accuracy: 95.70%
# Epoch: 10, Batch 600, Loss  0.7999
# Epoch: 10, Batch 1200, Loss  0.5162
# Epoch: 10, Batch 1800, Loss  0.1955
# Epoch: 10, Batch 2400, Loss  0.2411
# Epoch: 10, Batch 3000, Loss  0.7232
# Epoch: 10, Batch 3600, Loss  1.5284
# Epoch: 10, Batch 4200, Loss  0.1614
# Epoch: 10, Batch 4800, Loss  0.5476
# Epoch: 10, Batch 5400, Loss  0.3027
# Epoch: 10, Batch 6000, Loss  0.3627
# Epoch 10 — Train Accuracy: 85.60%
# Epoch 10 — Test Accuracy: 95.70%
# Epoch: 11, Batch 600, Loss  0.4408
# Epoch: 11, Batch 1200, Loss  0.2965
# Epoch: 11, Batch 1800, Loss  0.1847
# Epoch: 11, Batch 2400, Loss  0.1306
# Epoch: 11, Batch 3000, Loss  0.3411
# Epoch: 11, Batch 3600, Loss  0.2644
# Epoch: 11, Batch 4200, Loss  1.4021
# Epoch: 11, Batch 4800, Loss  0.4806
# Epoch: 11, Batch 5400, Loss  0.8001
# Epoch: 11, Batch 6000, Loss  0.1916
# Epoch 11 — Train Accuracy: 86.18%
# Epoch 11 — Test Accuracy: 96.53%
# Epoch: 12, Batch 600, Loss  1.3899
# Epoch: 12, Batch 1200, Loss  0.7458
# Epoch: 12, Batch 1800, Loss  1.2451
# Epoch: 12, Batch 2400, Loss  0.8030
# Epoch: 12, Batch 3000, Loss  1.1623
# Epoch: 12, Batch 3600, Loss  0.2386
# Epoch: 12, Batch 4200, Loss  0.5989
# Epoch: 12, Batch 4800, Loss  0.1174
# Epoch: 12, Batch 5400, Loss  0.4672
# Epoch: 12, Batch 6000, Loss  0.1268
# Epoch 12 — Train Accuracy: 86.48%
# Epoch 12 — Test Accuracy: 97.10%
# Epoch: 13, Batch 600, Loss  0.3251
# Epoch: 13, Batch 1200, Loss  0.7215
# Epoch: 13, Batch 1800, Loss  1.0007
# Epoch: 13, Batch 2400, Loss  1.1076
# Epoch: 13, Batch 3000, Loss  1.2308
# Epoch: 13, Batch 3600, Loss  1.2436
# Epoch: 13, Batch 4200, Loss  0.2319
# Epoch: 13, Batch 4800, Loss  1.1462
# Epoch: 13, Batch 5400, Loss  1.7478
# Epoch: 13, Batch 6000, Loss  1.1169
# Epoch 13 — Train Accuracy: 86.96%
# Epoch 13 — Test Accuracy: 97.02%
# Epoch: 14, Batch 600, Loss  0.1655
# Epoch: 14, Batch 1200, Loss  0.6654
# Epoch: 14, Batch 1800, Loss  0.5886
# Epoch: 14, Batch 2400, Loss  0.1258
# Epoch: 14, Batch 3000, Loss  0.6821
# Epoch: 14, Batch 3600, Loss  0.3664
# Epoch: 14, Batch 4200, Loss  0.3116
# Epoch: 14, Batch 4800, Loss  0.9289
# Epoch: 14, Batch 5400, Loss  0.2680
# Epoch: 14, Batch 6000, Loss  0.1962
# Epoch 14 — Train Accuracy: 87.11%
# Epoch 14 — Test Accuracy: 97.24%
# Epoch: 15, Batch 600, Loss  1.3328
# Epoch: 15, Batch 1200, Loss  0.1169
# Epoch: 15, Batch 1800, Loss  0.4735
# Epoch: 15, Batch 2400, Loss  0.2058
# Epoch: 15, Batch 3000, Loss  1.0321
# Epoch: 15, Batch 3600, Loss  0.2164
# Epoch: 15, Batch 4200, Loss  1.8660
# Epoch: 15, Batch 4800, Loss  1.4000
# Epoch: 15, Batch 5400, Loss  1.3191
# Epoch: 15, Batch 6000, Loss  0.3256
# Epoch 15 — Train Accuracy: 87.28%
# Epoch 15 — Test Accuracy: 97.27%

# %%
def compute_accuracy(correct_list, total_samples):
    return [100 * (x / total_samples) for x in correct_list]

train_acc = compute_accuracy(train_correct, len(trainLoader.dataset))
test_acc = compute_accuracy(test_correct, len(testLoader.dataset))

plt.figure(figsize=(12, 5))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(test_loss, label='Test Loss')
plt.title('Loss per Epoch (Poisoned CNN)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Accuracy')
plt.plot(test_acc, label='Test Accuracy')
plt.title('Accuracy per Epoch (Poisoned CNN)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()
